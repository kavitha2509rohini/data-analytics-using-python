# %% [markdown]
# <a href="https://colab.research.google.com/github/kavitha2509rohini/data-analytics-using-python/blob/main/day5.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# day 5 pandas

# %%
 import pandas as pd

data = pd.Series([10, 20, 30, 40, 50])
print(data)
# Out:
# 0    10
# 1    20
# 2    30
# 3    40
# 4    50
# dtype: int64

# %%
import pandas as pd

data = pd.Series(
    [100, 200, 300],
    index=["usha", "kavitha", "rani"]
)

print(data)
# Out:
# usha       100
# kavitha    200
# rani       300
# dtype: int64

# %%
import pandas as pd

employee = {
    "ID": [101, 102, 103],
    "Name": ["usha", "rani", "kavitha"],
    "salary": [5000, 70000, 6000]
}

df = pd.DataFrame(employee)
print(df)
# Out:
#     ID     Name  salary
# 0  101     usha    5000
# 1  102     rani   70000
# 2  103  kavitha    6000

# %%
import numpy as np
products=["laptop","mobile","tablet","headphone"]
sales=np.array([100200,300,400])
print("total sales:",np.sum(sales))
print("average sales:",np.mean(sales))
print("highest sales:",np.max(sales))
print("lowest sales:",np.min(sales))
# Out:
# total sales: 100900
# average sales: 33633.333333333336
# highest sales: 100200
# lowest sales: 300
