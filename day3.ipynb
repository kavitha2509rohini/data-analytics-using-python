# %% [markdown]
# <a href="https://colab.research.google.com/github/kavitha2509rohini/data-analytics-using-python/blob/main/day3.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
try:
    num = int(input("Enter Number:"))
    print(num)
except:
    print("invalid input")
# Out:
# Enter Number:55
# 55

# %%
import numpy as np

mark = np.array([90, 85, 78, 98])
print(mark)
# Out:
# [90 85 78 98]

# %%
import numpy as np

student = np.array([
    [90, 86],
    [88, 65],
    [44, 76]
])

print(student)
# Out:
# [[90 86]
#  [88 65]
#  [44 76]]

# %%
import numpy as np
arr=np.zeros((2,3))
print(arr)
# Out:
# [[0. 0. 0.]
#  [0. 0. 0.]]
